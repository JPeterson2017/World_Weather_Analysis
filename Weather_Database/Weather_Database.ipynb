# %%
import random
import pandas as pd
import numpy as np
import requests 

from config import weather_key
from citipy import citipy

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

lat_lngs = zip(lats, lngs)

# %%
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []

# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
#len(cities)

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_key

# %%
import time 
from datetime import datetime

# %%
# Create an empty list to hold the weather data
city_data = []

# Print the beginning of the logging
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in the list
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        # city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description
                          })

    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | mount isa
# Processing Record 2 of Set 1 | nikolskoye
# Processing Record 3 of Set 1 | srednekolymsk
# Processing Record 4 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 5 of Set 1 | bluff
# Processing Record 6 of Set 1 | port lincoln
# Processing Record 7 of Set 1 | arraial do cabo
# Processing Record 8 of Set 1 | alice springs
# Processing Record 9 of Set 1 | tuatapere
# Processing Record 10 of Set 1 | ahuimanu
# Processing Record 11 of Set 1 | rawson
# Processing Record 12 of Set 1 | kapaa
# Processing Record 13 of Set 1 | kushmurun
# Processing Record 14 of Set 1 | rikitea
# Processing Record 15 of Set 1 | lata
# Processing Record 16 of Set 1 | codrington
# Processing Record 17 of Set 1 | flin flon
# Processing Record 18 of Set 1 | vaini
# Processing Record 19 of Set 1 | busselton
# Processing Record 20 of Set 1 | myaundzha
# Processing Record 21 of Set 1 | mataura
# Processing Record 22 of Set 1 | jega
# Processing Record 23 of Set 1 | laguna
# Processing Record 24 of Set 1 | dunedin
# Processing Record 25 of Set 1 | faanui
# Processing Record 26 of Set 1 | lagoa
# Processing Record 27 of Set 1 | phonhong
# Processing Record 28 of Set 1 | provideniya
# Processing Record 29 of Set 1 | new norfolk
# Processing Record 30 of Set 1 | hithadhoo
# Processing Record 31 of Set 1 | awbari
# Processing Record 32 of Set 1 | haimen
# Processing Record 33 of Set 1 | kula
# Processing Record 34 of Set 1 | chokurdakh
# Processing Record 35 of Set 1 | albany
# Processing Record 36 of Set 1 | port macquarie
# Processing Record 37 of Set 1 | haines junction
# Processing Record 38 of Set 1 | glenwood springs
# Processing Record 39 of Set 1 | olymskiy
# City not found. Skipping...
# Processing Record 40 of Set 1 | nishihara
# Processing Record 41 of Set 1 | qaanaaq
# Processing Record 42 of Set 1 | palabuhanratu
# City not found. Skipping...
# Processing Record 43 of Set 1 | atuona
# Processing Record 44 of Set 1 | kahului
# Processing Record 45 of Set 1 | ushuaia
# Processing Record 46 of Set 1 | taltal
# Processing Record 47 of Set 1 | airai
# Processing Record 48 of Set 1 | tiksi
# Processing Record 49 of Set 1 | los llanos de aridane
# Processing Record 50 of Set 1 | kamenskoye
# City not found. Skipping...
# Processing Record 1 of Set 2 | gusau
# Processing Record 2 of Set 2 | dikson
# Processing Record 3 of Set 2 | aleksinac
# Processing Record 4 of Set 2 | paamiut
# Processing Record 5 of Set 2 | hilo
# Processing Record 6 of Set 2 | ponta do sol
# Processing Record 7 of Set 2 | louisbourg
# City not found. Skipping...
# Processing Record 8 of Set 2 | hualmay
# Processing Record 9 of Set 2 | turukhansk
# Processing Record 10 of Set 2 | adrar
# Processing Record 11 of Set 2 | kunashak
# Processing Record 12 of Set 2 | coquimbo
# Processing Record 13 of Set 2 | linhai
# Processing Record 14 of Set 2 | bridlington
# Processing Record 15 of Set 2 | acari
# Processing Record 16 of Set 2 | cidreira
# Processing Record 17 of Set 2 | east london
# Processing Record 18 of Set 2 | punta arenas
# Processing Record 19 of Set 2 | waingapu
# Processing Record 20 of Set 2 | port elizabeth
# Processing Record 21 of Set 2 | salacgriva
# Processing Record 22 of Set 2 | georgetown
# Processing Record 23 of Set 2 | saint-philippe
# Processing Record 24 of Set 2 | babanusah
# City not found. Skipping...
# Processing Record 25 of Set 2 | cape town
# Processing Record 26 of Set 2 | ponta delgada
# Processing Record 27 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 28 of Set 2 | dalvik
# Processing Record 29 of Set 2 | sompeta
# Processing Record 30 of Set 2 | hambantota
# Processing Record 31 of Set 2 | andevoranto
# City not found. Skipping...
# Processing Record 32 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 33 of Set 2 | khatanga
# Processing Record 34 of Set 2 | el tocuyo
# Processing Record 35 of Set 2 | puerto ayora
# Processing Record 36 of Set 2 | port alfred
# Processing Record 37 of Set 2 | gulshat
# City not found. Skipping...
# Processing Record 38 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 39 of Set 2 | hermanus
# Processing Record 40 of Set 2 | cabo san lucas
# Processing Record 41 of Set 2 | el balyana
# City not found. Skipping...
# Processing Record 42 of Set 2 | vanimo
# Processing Record 43 of Set 2 | college
# Processing Record 44 of Set 2 | maketu
# Processing Record 45 of Set 2 | barrow
# Processing Record 46 of Set 2 | chuy
# Processing Record 47 of Set 2 | castro
# Processing Record 48 of Set 2 | san jose
# Processing Record 49 of Set 2 | north platte
# Processing Record 50 of Set 2 | thompson
# Processing Record 1 of Set 3 | sorvag
# City not found. Skipping...
# Processing Record 2 of Set 3 | saskylakh
# Processing Record 3 of Set 3 | wuwei
# Processing Record 4 of Set 3 | dolbeau
# City not found. Skipping...
# Processing Record 5 of Set 3 | jodhpur
# Processing Record 6 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 7 of Set 3 | millau
# Processing Record 8 of Set 3 | pisco
# Processing Record 9 of Set 3 | tiarei
# Processing Record 10 of Set 3 | broome
# Processing Record 11 of Set 3 | mareeba
# Processing Record 12 of Set 3 | jamestown
# Processing Record 13 of Set 3 | mehamn
# Processing Record 14 of Set 3 | constitucion
# Processing Record 15 of Set 3 | yellowknife
# Processing Record 16 of Set 3 | avera
# Processing Record 17 of Set 3 | subate
# Processing Record 18 of Set 3 | kpandae
# Processing Record 19 of Set 3 | sur
# Processing Record 20 of Set 3 | champerico
# Processing Record 21 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 22 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 23 of Set 3 | lamballe
# Processing Record 24 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 25 of Set 3 | santarem
# Processing Record 26 of Set 3 | eston
# Processing Record 27 of Set 3 | opuwo
# Processing Record 28 of Set 3 | bredasdorp
# Processing Record 29 of Set 3 | matagami
# Processing Record 30 of Set 3 | sobolevo
# Processing Record 31 of Set 3 | abu kamal
# Processing Record 32 of Set 3 | pingliang
# Processing Record 33 of Set 3 | tyshkivka
# Processing Record 34 of Set 3 | bacuit
# City not found. Skipping...
# Processing Record 35 of Set 3 | devonport
# Processing Record 36 of Set 3 | bethel
# Processing Record 37 of Set 3 | camacha
# Processing Record 38 of Set 3 | victoria
# Processing Record 39 of Set 3 | amot
# Processing Record 40 of Set 3 | torbay
# Processing Record 41 of Set 3 | holme
# Processing Record 42 of Set 3 | poronaysk
# Processing Record 43 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 44 of Set 3 | impfondo
# Processing Record 45 of Set 3 | mezdra
# Processing Record 46 of Set 3 | jesup
# Processing Record 47 of Set 3 | dabakala
# Processing Record 48 of Set 3 | la asuncion
# Processing Record 49 of Set 3 | chutung
# City not found. Skipping...
# Processing Record 50 of Set 3 | tasiilaq
# Processing Record 1 of Set 4 | bolungarvik
# City not found. Skipping...
# Processing Record 2 of Set 4 | butaritari
# Processing Record 3 of Set 4 | grand gaube
# Processing Record 4 of Set 4 | saint george
# Processing Record 5 of Set 4 | mahebourg
# Processing Record 6 of Set 4 | launceston
# Processing Record 7 of Set 4 | tenosique
# Processing Record 8 of Set 4 | dinsor
# City not found. Skipping...
# Processing Record 9 of Set 4 | chapais
# Processing Record 10 of Set 4 | caravelas
# Processing Record 11 of Set 4 | san patricio
# Processing Record 12 of Set 4 | winnemucca
# Processing Record 13 of Set 4 | fortuna
# Processing Record 14 of Set 4 | maarianhamina
# Processing Record 15 of Set 4 | kodiak
# Processing Record 16 of Set 4 | zaozerne
# Processing Record 17 of Set 4 | chumikan
# Processing Record 18 of Set 4 | souillac
# Processing Record 19 of Set 4 | tuktoyaktuk
# Processing Record 20 of Set 4 | ribeira grande
# Processing Record 21 of Set 4 | severo-kurilsk
# Processing Record 22 of Set 4 | valera
# Processing Record 23 of Set 4 | lebu
# Processing Record 24 of Set 4 | half moon bay
# Processing Record 25 of Set 4 | mercato san severino
# Processing Record 26 of Set 4 | ust-bolsheretsk
# City not found. Skipping...
# Processing Record 27 of Set 4 | broken hill
# Processing Record 28 of Set 4 | pevek
# Processing Record 29 of Set 4 | nipawin
# Processing Record 30 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 31 of Set 4 | rodrigues alves
# Processing Record 32 of Set 4 | khategaon
# Processing Record 33 of Set 4 | hasaki
# Processing Record 34 of Set 4 | hobart
# Processing Record 35 of Set 4 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 36 of Set 4 | dayong
# Processing Record 37 of Set 4 | salalah
# Processing Record 38 of Set 4 | maniitsoq
# Processing Record 39 of Set 4 | bengkulu
# Processing Record 40 of Set 4 | tateyama
# Processing Record 41 of Set 4 | salinas
# Processing Record 42 of Set 4 | sistranda
# Processing Record 43 of Set 4 | krasnyy chikoy
# Processing Record 44 of Set 4 | mnogovershinnyy
# Processing Record 45 of Set 4 | kruisfontein
# Processing Record 46 of Set 4 | carnarvon
# Processing Record 47 of Set 4 | chara
# Processing Record 48 of Set 4 | faya
# Processing Record 49 of Set 4 | kaitangata
# Processing Record 50 of Set 4 | kuah
# Processing Record 1 of Set 5 | itacare
# Processing Record 2 of Set 5 | klaksvik
# Processing Record 3 of Set 5 | muriwai beach
# Processing Record 4 of Set 5 | karla
# Processing Record 5 of Set 5 | rungata
# City not found. Skipping...
# Processing Record 6 of Set 5 | ust-nera
# Processing Record 7 of Set 5 | avarua
# Processing Record 8 of Set 5 | wanning
# Processing Record 9 of Set 5 | havelock
# Processing Record 10 of Set 5 | beringovskiy
# Processing Record 11 of Set 5 | itarema
# Processing Record 12 of Set 5 | vao
# Processing Record 13 of Set 5 | upernavik
# Processing Record 14 of Set 5 | mangochi
# Processing Record 15 of Set 5 | wladyslawowo
# Processing Record 16 of Set 5 | rocha
# Processing Record 17 of Set 5 | acarau
# Processing Record 18 of Set 5 | pacific grove
# Processing Record 19 of Set 5 | westport
# Processing Record 20 of Set 5 | luebo
# Processing Record 21 of Set 5 | marystown
# Processing Record 22 of Set 5 | conde
# Processing Record 23 of Set 5 | gidole
# Processing Record 24 of Set 5 | shelburne
# Processing Record 25 of Set 5 | fonte boa
# Processing Record 26 of Set 5 | ak-dovurak
# Processing Record 27 of Set 5 | the valley
# Processing Record 28 of Set 5 | ketchikan
# Processing Record 29 of Set 5 | west wendover
# Processing Record 30 of Set 5 | saint anthony
# Processing Record 31 of Set 5 | mengcheng
# Processing Record 32 of Set 5 | bubaque
# Processing Record 33 of Set 5 | sebastian
# Processing Record 34 of Set 5 | bathsheba
# Processing Record 35 of Set 5 | narsaq
# Processing Record 36 of Set 5 | angoche
# Processing Record 37 of Set 5 | warri
# Processing Record 38 of Set 5 | bolshoye nagatkino
# Processing Record 39 of Set 5 | cherskiy
# Processing Record 40 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 41 of Set 5 | shihezi
# Processing Record 42 of Set 5 | awjilah
# Processing Record 43 of Set 5 | tiznit
# Processing Record 44 of Set 5 | farafangana
# Processing Record 45 of Set 5 | chancay
# Processing Record 46 of Set 5 | hamilton
# Processing Record 47 of Set 5 | geraldton
# Processing Record 48 of Set 5 | ugoofaaru
# Processing Record 49 of Set 5 | kavieng
# Processing Record 50 of Set 5 | jujuy
# City not found. Skipping...
# Processing Record 1 of Set 6 | northam
# Processing Record 2 of Set 6 | bowen
# Processing Record 3 of Set 6 | utiroa
# City not found. Skipping...
# Processing Record 4 of Set 6 | yarmouth
# Processing Record 5 of Set 6 | dongsheng
# Processing Record 6 of Set 6 | cortez
# Processing Record 7 of Set 6 | dumas
# Processing Record 8 of Set 6 | puerto el triunfo
# Processing Record 9 of Set 6 | ambon
# Processing Record 10 of Set 6 | husavik
# Processing Record 11 of Set 6 | owando
# Processing Record 12 of Set 6 | beroroha
# Processing Record 13 of Set 6 | lorengau
# Processing Record 14 of Set 6 | jiangkou
# Processing Record 15 of Set 6 | walvis bay
# Processing Record 16 of Set 6 | nantucket
# Processing Record 17 of Set 6 | cayenne
# Processing Record 18 of Set 6 | ilulissat
# Processing Record 19 of Set 6 | chicama
# Processing Record 20 of Set 6 | goderich
# Processing Record 21 of Set 6 | poum
# Processing Record 22 of Set 6 | port hedland
# Processing Record 23 of Set 6 | erzin
# Processing Record 24 of Set 6 | mujiayingzi
# Processing Record 25 of Set 6 | merseburg
# Processing Record 26 of Set 6 | bilma
# Processing Record 27 of Set 6 | brazzaville
# Processing Record 28 of Set 6 | omboue
# Processing Record 29 of Set 6 | monastyrshchina
# Processing Record 30 of Set 6 | caracuaro
# Processing Record 31 of Set 6 | mazyr
# Processing Record 32 of Set 6 | muros
# Processing Record 33 of Set 6 | bambous virieux
# Processing Record 34 of Set 6 | kyshtovka
# Processing Record 35 of Set 6 | batouri
# Processing Record 36 of Set 6 | gushikawa
# Processing Record 37 of Set 6 | kayerkan
# Processing Record 38 of Set 6 | luderitz
# Processing Record 39 of Set 6 | mogadouro
# Processing Record 40 of Set 6 | bereda
# Processing Record 41 of Set 6 | bajil
# Processing Record 42 of Set 6 | seoul
# Processing Record 43 of Set 6 | north bend
# Processing Record 44 of Set 6 | puerto madero
# Processing Record 45 of Set 6 | phangnga
# Processing Record 46 of Set 6 | touros
# Processing Record 47 of Set 6 | zyryanka
# Processing Record 48 of Set 6 | mayumba
# Processing Record 49 of Set 6 | goure
# Processing Record 50 of Set 6 | masallatah
# Processing Record 1 of Set 7 | vagur
# Processing Record 2 of Set 7 | oriximina
# Processing Record 3 of Set 7 | svetlaya
# Processing Record 4 of Set 7 | beremend
# Processing Record 5 of Set 7 | katobu
# Processing Record 6 of Set 7 | burica
# City not found. Skipping...
# Processing Record 7 of Set 7 | cumbum
# Processing Record 8 of Set 7 | yamada
# Processing Record 9 of Set 7 | graaff-reinet
# Processing Record 10 of Set 7 | norman wells
# Processing Record 11 of Set 7 | tangzhai
# Processing Record 12 of Set 7 | zambezi
# Processing Record 13 of Set 7 | buenos aires
# Processing Record 14 of Set 7 | eyemouth
# Processing Record 15 of Set 7 | harlingen
# Processing Record 16 of Set 7 | barentsburg
# City not found. Skipping...
# Processing Record 17 of Set 7 | portland
# Processing Record 18 of Set 7 | port blair
# Processing Record 19 of Set 7 | ushtobe
# Processing Record 20 of Set 7 | petropavlovsk-kamchatskiy
# Processing Record 21 of Set 7 | crab hill
# City not found. Skipping...
# Processing Record 22 of Set 7 | dekar
# Processing Record 23 of Set 7 | wuan
# Processing Record 24 of Set 7 | guerrero negro
# Processing Record 25 of Set 7 | panguna
# Processing Record 26 of Set 7 | turbat
# Processing Record 27 of Set 7 | ostrovnoy
# Processing Record 28 of Set 7 | alofi
# Processing Record 29 of Set 7 | khonuu
# City not found. Skipping...
# Processing Record 30 of Set 7 | ormara
# Processing Record 31 of Set 7 | turiacu
# Processing Record 32 of Set 7 | ahipara
# Processing Record 33 of Set 7 | brokopondo
# Processing Record 34 of Set 7 | banda aceh
# Processing Record 35 of Set 7 | barra do garcas
# Processing Record 36 of Set 7 | pouebo
# Processing Record 37 of Set 7 | divnoye
# Processing Record 38 of Set 7 | porto walter
# Processing Record 39 of Set 7 | mormugao
# Processing Record 40 of Set 7 | powell river
# Processing Record 41 of Set 7 | shache
# Processing Record 42 of Set 7 | severnoye
# Processing Record 43 of Set 7 | salinopolis
# Processing Record 44 of Set 7 | san cristobal
# Processing Record 45 of Set 7 | lundazi
# Processing Record 46 of Set 7 | charlestown
# Processing Record 47 of Set 7 | tabiauea
# City not found. Skipping...
# Processing Record 48 of Set 7 | bismarck
# Processing Record 49 of Set 7 | ukiah
# Processing Record 50 of Set 7 | swellendam
# Processing Record 1 of Set 8 | krotoszyn
# Processing Record 2 of Set 8 | vila franca do campo
# Processing Record 3 of Set 8 | longlac
# City not found. Skipping...
# Processing Record 4 of Set 8 | katherine
# Processing Record 5 of Set 8 | vestmanna
# Processing Record 6 of Set 8 | kudahuvadhoo
# Processing Record 7 of Set 8 | puri
# Processing Record 8 of Set 8 | twentynine palms
# Processing Record 9 of Set 8 | buraydah
# Processing Record 10 of Set 8 | chernyshevskiy
# Processing Record 11 of Set 8 | ust-tsilma
# Processing Record 12 of Set 8 | muswellbrook
# Processing Record 13 of Set 8 | chakwal
# Processing Record 14 of Set 8 | wuzhou
# Processing Record 15 of Set 8 | flinders
# Processing Record 16 of Set 8 | innisfail
# Processing Record 17 of Set 8 | lima
# Processing Record 18 of Set 8 | aykhal
# Processing Record 19 of Set 8 | ostersund
# Processing Record 20 of Set 8 | mys shmidta
# City not found. Skipping...
# Processing Record 21 of Set 8 | rundu
# Processing Record 22 of Set 8 | williston
# Processing Record 23 of Set 8 | balakhninskiy
# Processing Record 24 of Set 8 | mar del plata
# Processing Record 25 of Set 8 | meyungs
# City not found. Skipping...
# Processing Record 26 of Set 8 | clyde river
# Processing Record 27 of Set 8 | brigantine
# Processing Record 28 of Set 8 | yumen
# Processing Record 29 of Set 8 | olafsvik
# Processing Record 30 of Set 8 | amahai
# Processing Record 31 of Set 8 | magdagachi
# Processing Record 32 of Set 8 | isangel
# Processing Record 33 of Set 8 | porto novo
# Processing Record 34 of Set 8 | moree
# Processing Record 35 of Set 8 | methoni
# Processing Record 36 of Set 8 | nuuk
# Processing Record 37 of Set 8 | jumla
# Processing Record 38 of Set 8 | ombessa
# Processing Record 39 of Set 8 | saldanha
# Processing Record 40 of Set 8 | fort nelson
# Processing Record 41 of Set 8 | leshukonskoye
# Processing Record 42 of Set 8 | huarmey
# Processing Record 43 of Set 8 | nemuro
# Processing Record 44 of Set 8 | rudbar
# Processing Record 45 of Set 8 | leningradskiy
# Processing Record 46 of Set 8 | mouila
# Processing Record 47 of Set 8 | santa vitoria do palmar
# Processing Record 48 of Set 8 | sydney
# Processing Record 49 of Set 8 | bantry
# Processing Record 50 of Set 8 | moiyabana
# City not found. Skipping...
# Processing Record 1 of Set 9 | harindanga
# Processing Record 2 of Set 9 | zaraza
# Processing Record 3 of Set 9 | biltine
# Processing Record 4 of Set 9 | nalut
# Processing Record 5 of Set 9 | evensk
# Processing Record 6 of Set 9 | gilgit
# Processing Record 7 of Set 9 | tripoli
# Processing Record 8 of Set 9 | jaisalmer
# Processing Record 9 of Set 9 | te anau
# Processing Record 10 of Set 9 | ballina
# Processing Record 11 of Set 9 | biak
# Processing Record 12 of Set 9 | les cayes
# Processing Record 13 of Set 9 | mungwi
# Processing Record 14 of Set 9 | ngukurr
# City not found. Skipping...
# Processing Record 15 of Set 9 | dongli
# Processing Record 16 of Set 9 | naze
# Processing Record 17 of Set 9 | nanakuli
# Processing Record 18 of Set 9 | dawson creek
# Processing Record 19 of Set 9 | kahramanmaras
# Processing Record 20 of Set 9 | samarai
# Processing Record 21 of Set 9 | batagay-alyta
# Processing Record 22 of Set 9 | yulara
# Processing Record 23 of Set 9 | miramar
# Processing Record 24 of Set 9 | mogadishu
# Processing Record 25 of Set 9 | wellington
# Processing Record 26 of Set 9 | puerto narino
# Processing Record 27 of Set 9 | qaqortoq
# Processing Record 28 of Set 9 | quatre cocos
# Processing Record 29 of Set 9 | malakal
# Processing Record 30 of Set 9 | bria
# Processing Record 31 of Set 9 | cabra
# Processing Record 32 of Set 9 | daru
# Processing Record 33 of Set 9 | perth
# Processing Record 34 of Set 9 | noumea
# Processing Record 35 of Set 9 | milkovo
# Processing Record 36 of Set 9 | katsuura
# Processing Record 37 of Set 9 | raga
# Processing Record 38 of Set 9 | abbeville
# Processing Record 39 of Set 9 | yar-sale
# Processing Record 40 of Set 9 | la ronge
# Processing Record 41 of Set 9 | sao joao do paraiso
# Processing Record 42 of Set 9 | vicuna
# Processing Record 43 of Set 9 | merauke
# Processing Record 44 of Set 9 | moose factory
# Processing Record 45 of Set 9 | salgar
# Processing Record 46 of Set 9 | cherepovets
# Processing Record 47 of Set 9 | xuddur
# Processing Record 48 of Set 9 | sao filipe
# Processing Record 49 of Set 9 | kutum
# Processing Record 50 of Set 9 | kokkola
# Processing Record 1 of Set 10 | nouadhibou
# Processing Record 2 of Set 10 | urumqi
# Processing Record 3 of Set 10 | bardiyah
# Processing Record 4 of Set 10 | asfi
# Processing Record 5 of Set 10 | batagay
# Processing Record 6 of Set 10 | maragogi
# Processing Record 7 of Set 10 | maningrida
# Processing Record 8 of Set 10 | vilyuysk
# Processing Record 9 of Set 10 | toamasina
# Processing Record 10 of Set 10 | namibe
# Processing Record 11 of Set 10 | itupiranga
# Processing Record 12 of Set 10 | hervey bay
# Processing Record 13 of Set 10 | comodoro rivadavia
# Processing Record 14 of Set 10 | longyearbyen
# Processing Record 15 of Set 10 | bairiki
# Processing Record 16 of Set 10 | vryburg
# Processing Record 17 of Set 10 | brae
# Processing Record 18 of Set 10 | grindavik
# Processing Record 19 of Set 10 | nizwa
# Processing Record 20 of Set 10 | jalu
# Processing Record 21 of Set 10 | itaituba
# Processing Record 22 of Set 10 | southbridge
# Processing Record 23 of Set 10 | progreso
# Processing Record 24 of Set 10 | aksarka
# Processing Record 25 of Set 10 | buala
# Processing Record 26 of Set 10 | palmer
# Processing Record 27 of Set 10 | sardarshahr
# Processing Record 28 of Set 10 | ayia galini
# Processing Record 29 of Set 10 | methven
# Processing Record 30 of Set 10 | port hardy
# Processing Record 31 of Set 10 | camopi
# Processing Record 32 of Set 10 | sayansk
# Processing Record 33 of Set 10 | gizo
# Processing Record 34 of Set 10 | ginda
# Processing Record 35 of Set 10 | mustafakemalpasa
# Processing Record 36 of Set 10 | port-gentil
# Processing Record 37 of Set 10 | romitan
# Processing Record 38 of Set 10 | kirakira
# Processing Record 39 of Set 10 | krosno
# Processing Record 40 of Set 10 | ankang
# Processing Record 41 of Set 10 | lahat
# Processing Record 42 of Set 10 | quimperle
# Processing Record 43 of Set 10 | port keats
# Processing Record 44 of Set 10 | changping
# Processing Record 45 of Set 10 | kargil
# Processing Record 46 of Set 10 | verpelet
# Processing Record 47 of Set 10 | jinchengjiang
# City not found. Skipping...
# Processing Record 48 of Set 10 | aklavik
# Processing Record 49 of Set 10 | vilhena
# Processing Record 50 of Set 10 | sibolga
# Processing Record 1 of Set 11 | eldorado
# Processing Record 2 of Set 11 | pangnirtung
# Processing Record 3 of Set 11 | kenai
# Processing Record 4 of Set 11 | salo
# Processing Record 5 of Set 11 | kogon
# Processing Record 6 of Set 11 | axim
# Processing Record 7 of Set 11 | celestun
# Processing Record 8 of Set 11 | mount gambier
# Processing Record 9 of Set 11 | riviere-du-loup
# Processing Record 10 of Set 11 | kanniyakumari
# Processing Record 11 of Set 11 | barra do corda
# Processing Record 12 of Set 11 | saint-pierre
# Processing Record 13 of Set 11 | la paz centro
# Processing Record 14 of Set 11 | takhtamygda
# Processing Record 15 of Set 11 | waterloo
# Processing Record 16 of Set 11 | fallon
# Processing Record 17 of Set 11 | itabera
# Processing Record 18 of Set 11 | san carlos
# Processing Record 19 of Set 11 | sao miguel do araguaia
# Processing Record 20 of Set 11 | ulladulla
# Processing Record 21 of Set 11 | merrill
# Processing Record 22 of Set 11 | medicine hat
# Processing Record 23 of Set 11 | paratinga
# Processing Record 24 of Set 11 | okakarara
# Processing Record 25 of Set 11 | adamovka
# Processing Record 26 of Set 11 | okahandja
# Processing Record 27 of Set 11 | zhigansk
# Processing Record 28 of Set 11 | mpanda
# Processing Record 29 of Set 11 | praia
# Processing Record 30 of Set 11 | sinkat
# City not found. Skipping...
# Processing Record 31 of Set 11 | sitka
# Processing Record 32 of Set 11 | tura
# Processing Record 33 of Set 11 | acapulco
# Processing Record 34 of Set 11 | pathri
# Processing Record 35 of Set 11 | kharp
# Processing Record 36 of Set 11 | severobaykalsk
# Processing Record 37 of Set 11 | tampakan
# Processing Record 38 of Set 11 | cooma
# Processing Record 39 of Set 11 | tidore
# City not found. Skipping...
# Processing Record 40 of Set 11 | fayaoue
# Processing Record 41 of Set 11 | eganville
# Processing Record 42 of Set 11 | humaita
# Processing Record 43 of Set 11 | satitoa
# City not found. Skipping...
# Processing Record 44 of Set 11 | fukue
# Processing Record 45 of Set 11 | pingxiang
# Processing Record 46 of Set 11 | marsabit
# Processing Record 47 of Set 11 | harper
# Processing Record 48 of Set 11 | malwan
# City not found. Skipping...
# Processing Record 49 of Set 11 | yarim
# Processing Record 50 of Set 11 | marrakesh
# Processing Record 1 of Set 12 | sofiysk
# City not found. Skipping...
# Processing Record 2 of Set 12 | ayan
# Processing Record 3 of Set 12 | puerto escondido
# Processing Record 4 of Set 12 | gharghoda
# Processing Record 5 of Set 12 | huntington
# Processing Record 6 of Set 12 | deputatskiy
# Processing Record 7 of Set 12 | folldal
# Processing Record 8 of Set 12 | durres
# Processing Record 9 of Set 12 | alta floresta
# Processing Record 10 of Set 12 | nanortalik
# Processing Record 11 of Set 12 | beloha
# Processing Record 12 of Set 12 | gondanglegi
# Processing Record 13 of Set 12 | uwayl
# City not found. Skipping...
# Processing Record 14 of Set 12 | conway
# Processing Record 15 of Set 12 | krasnovishersk
# Processing Record 16 of Set 12 | nautla
# Processing Record 17 of Set 12 | gambissara
# Processing Record 18 of Set 12 | manono
# Processing Record 19 of Set 12 | shu
# Processing Record 20 of Set 12 | kajaani
# Processing Record 21 of Set 12 | kapit
# Processing Record 22 of Set 12 | gigmoto
# Processing Record 23 of Set 12 | genhe
# Processing Record 24 of Set 12 | calama
# Processing Record 25 of Set 12 | yarada
# Processing Record 26 of Set 12 | nenjiang
# Processing Record 27 of Set 12 | manoel urbano
# Processing Record 28 of Set 12 | namatanai
# Processing Record 29 of Set 12 | marcona
# City not found. Skipping...
# Processing Record 30 of Set 12 | tubruq
# City not found. Skipping...
# Processing Record 31 of Set 12 | byron bay
# Processing Record 32 of Set 12 | barnstaple
# Processing Record 33 of Set 12 | kvam
# Processing Record 34 of Set 12 | sinnamary
# Processing Record 35 of Set 12 | igarka
# Processing Record 36 of Set 12 | ulaanbaatar
# Processing Record 37 of Set 12 | oktyabrskiy
# Processing Record 38 of Set 12 | ferrol
# Processing Record 39 of Set 12 | mitchell
# Processing Record 40 of Set 12 | dhidhdhoo
# Processing Record 41 of Set 12 | gat
# Processing Record 42 of Set 12 | umzimvubu
# City not found. Skipping...
# Processing Record 43 of Set 12 | roald
# Processing Record 44 of Set 12 | lompoc
# Processing Record 45 of Set 12 | santa cruz
# Processing Record 46 of Set 12 | lasa
# Processing Record 47 of Set 12 | kadykchan
# City not found. Skipping...
# Processing Record 48 of Set 12 | karkaralinsk
# City not found. Skipping...
# Processing Record 49 of Set 12 | fiche
# Processing Record 50 of Set 12 | alihe
# Processing Record 1 of Set 13 | olean
# Processing Record 2 of Set 13 | uyuni
# Processing Record 3 of Set 13 | urengoy
# Processing Record 4 of Set 13 | jiddah
# City not found. Skipping...
# Processing Record 5 of Set 13 | nuevo casas grandes
# Processing Record 6 of Set 13 | durango
# Processing Record 7 of Set 13 | ishinomaki
# Processing Record 8 of Set 13 | ajdabiya
# Processing Record 9 of Set 13 | itaueira
# Processing Record 10 of Set 13 | ancud
# Processing Record 11 of Set 13 | tornio
# Processing Record 12 of Set 13 | zhangjiakou
# Processing Record 13 of Set 13 | ginir
# Processing Record 14 of Set 13 | kuusamo
# Processing Record 15 of Set 13 | wilmington
# Processing Record 16 of Set 13 | rawannawi
# City not found. Skipping...
# Processing Record 17 of Set 13 | osmena
# Processing Record 18 of Set 13 | nivala
# Processing Record 19 of Set 13 | ekhabi
# Processing Record 20 of Set 13 | lons-le-saunier
# Processing Record 21 of Set 13 | dengzhou
# Processing Record 22 of Set 13 | la rioja
# Processing Record 23 of Set 13 | luganville
# Processing Record 24 of Set 13 | amderma
# City not found. Skipping...
# Processing Record 25 of Set 13 | ngemplak
# Processing Record 26 of Set 13 | boden
# Processing Record 27 of Set 13 | achisay
# City not found. Skipping...
# Processing Record 28 of Set 13 | calpan
# City not found. Skipping...
# Processing Record 29 of Set 13 | narsimhapur
# Processing Record 30 of Set 13 | okhotsk
# Processing Record 31 of Set 13 | buchanan
# Processing Record 32 of Set 13 | sambava
# Processing Record 33 of Set 13 | jiancheng
# Processing Record 34 of Set 13 | barcelos
# Processing Record 35 of Set 13 | cangzhou
# Processing Record 36 of Set 13 | sumbawa
# City not found. Skipping...
# Processing Record 37 of Set 13 | sarkand
# Processing Record 38 of Set 13 | sainte-marie
# Processing Record 39 of Set 13 | kikwit
# Processing Record 40 of Set 13 | urucara
# Processing Record 41 of Set 13 | kirkuk
# Processing Record 42 of Set 13 | fairbanks
# Processing Record 43 of Set 13 | treinta y tres
# Processing Record 44 of Set 13 | pestovo
# Processing Record 45 of Set 13 | nchelenge
# Processing Record 46 of Set 13 | bandar-e lengeh
# Processing Record 47 of Set 13 | lavrentiya
# Processing Record 48 of Set 13 | menongue
# Processing Record 49 of Set 13 | jacareacanga
# Processing Record 50 of Set 13 | pirovskoye
# Processing Record 1 of Set 14 | morros
# Processing Record 2 of Set 14 | hernani
# Processing Record 3 of Set 14 | lazaro cardenas
# Processing Record 4 of Set 14 | antigonish
# Processing Record 5 of Set 14 | juneau
# Processing Record 6 of Set 14 | meadow lake
# Processing Record 7 of Set 14 | nushki
# Processing Record 8 of Set 14 | uray
# Processing Record 9 of Set 14 | shimoda
# Processing Record 10 of Set 14 | kaita
# Processing Record 11 of Set 14 | deh rawud
# City not found. Skipping...
# Processing Record 12 of Set 14 | tezu
# Processing Record 13 of Set 14 | kyren
# Processing Record 14 of Set 14 | delijan
# Processing Record 15 of Set 14 | mikun
# Processing Record 16 of Set 14 | lolua
# City not found. Skipping...
# Processing Record 17 of Set 14 | newport
# Processing Record 18 of Set 14 | mrirt
# City not found. Skipping...
# Processing Record 19 of Set 14 | beidao
# Processing Record 20 of Set 14 | mackenzie
# Processing Record 21 of Set 14 | vila velha
# Processing Record 22 of Set 14 | caorle
# Processing Record 23 of Set 14 | usinsk
# Processing Record 24 of Set 14 | solano
# Processing Record 25 of Set 14 | inhambane
# Processing Record 26 of Set 14 | istok
# Processing Record 27 of Set 14 | ankazobe
# Processing Record 28 of Set 14 | meulaboh
# Processing Record 29 of Set 14 | cehegin
# Processing Record 30 of Set 14 | san quintin
# Processing Record 31 of Set 14 | pringsewu
# Processing Record 32 of Set 14 | dyurtyuli
# Processing Record 33 of Set 14 | sira
# Processing Record 34 of Set 14 | alamogordo
# Processing Record 35 of Set 14 | staraya kulatka
# Processing Record 36 of Set 14 | bossembele
# City not found. Skipping...
# Processing Record 37 of Set 14 | najran
# Processing Record 38 of Set 14 | banjar
# Processing Record 39 of Set 14 | mullaitivu
# City not found. Skipping...
# Processing Record 40 of Set 14 | mompos
# Processing Record 41 of Set 14 | sorland
# Processing Record 42 of Set 14 | douglas
# Processing Record 43 of Set 14 | gornopravdinsk
# Processing Record 44 of Set 14 | ono
# Processing Record 45 of Set 14 | baruun-urt
# Processing Record 46 of Set 14 | pareora
# Processing Record 47 of Set 14 | tombouctou
# Processing Record 48 of Set 14 | labutta
# City not found. Skipping...
# Processing Record 49 of Set 14 | dingle
# Processing Record 50 of Set 14 | pontian kecil
# Processing Record 1 of Set 15 | praya
# Processing Record 2 of Set 15 | mutsamudu
# City not found. Skipping...
# Processing Record 3 of Set 15 | ternate
# Processing Record 4 of Set 15 | novobataysk
# Processing Record 5 of Set 15 | labuhan
# Processing Record 6 of Set 15 | kokoda
# Processing Record 7 of Set 15 | bereznik
# Processing Record 8 of Set 15 | tarapur
# Processing Record 9 of Set 15 | viligili
# City not found. Skipping...
# Processing Record 10 of Set 15 | mandera
# Processing Record 11 of Set 15 | toliary
# City not found. Skipping...
# Processing Record 12 of Set 15 | oudtshoorn
# Processing Record 13 of Set 15 | vercheres
# Processing Record 14 of Set 15 | almaznyy
# Processing Record 15 of Set 15 | ballinasloe
# Processing Record 16 of Set 15 | carauari
# Processing Record 17 of Set 15 | hohhot
# Processing Record 18 of Set 15 | manggar
# Processing Record 19 of Set 15 | lincoln
# Processing Record 20 of Set 15 | asau
# Processing Record 21 of Set 15 | ribas do rio pardo
# Processing Record 22 of Set 15 | columbia
# Processing Record 23 of Set 15 | tukrah
# Processing Record 24 of Set 15 | cabedelo
# Processing Record 25 of Set 15 | bom jesus
# Processing Record 26 of Set 15 | yenotayevka
# Processing Record 27 of Set 15 | tamandare
# Processing Record 28 of Set 15 | khalabat
# Processing Record 29 of Set 15 | ambilobe
# Processing Record 30 of Set 15 | yaan
# Processing Record 31 of Set 15 | qiongshan
# Processing Record 32 of Set 15 | iqaluit
# Processing Record 33 of Set 15 | shingu
# Processing Record 34 of Set 15 | strelka
# Processing Record 35 of Set 15 | ikom
# Processing Record 36 of Set 15 | luanda
# Processing Record 37 of Set 15 | wamba
# Processing Record 38 of Set 15 | kvarkeno
# Processing Record 39 of Set 15 | roma
# Processing Record 40 of Set 15 | galiwinku
# City not found. Skipping...
# Processing Record 41 of Set 15 | aberdeen
# Processing Record 42 of Set 15 | tual
# Processing Record 43 of Set 15 | anaconda
# Processing Record 44 of Set 15 | kichera
# Processing Record 45 of Set 15 | harboore
# Processing Record 46 of Set 15 | cap malheureux
# Processing Record 47 of Set 15 | shenzhen
# Processing Record 48 of Set 15 | dakar
# Processing Record 49 of Set 15 | belyy yar
# Processing Record 50 of Set 15 | waxahachie
# Processing Record 1 of Set 16 | krasnoyarsk-45
# City not found. Skipping...
# Processing Record 2 of Set 16 | oranjemund
# Processing Record 3 of Set 16 | la tuque
# Processing Record 4 of Set 16 | xining
# Processing Record 5 of Set 16 | pichayevo
# Processing Record 6 of Set 16 | verkhnyaya inta
# Processing Record 7 of Set 16 | thesprotikon
# Processing Record 8 of Set 16 | general roca
# Processing Record 9 of Set 16 | tasbuget
# City not found. Skipping...
# Processing Record 10 of Set 16 | taoudenni
# Processing Record 11 of Set 16 | torquay
# Processing Record 12 of Set 16 | midyat
# Processing Record 13 of Set 16 | solnechnyy
# Processing Record 14 of Set 16 | viedma
# Processing Record 15 of Set 16 | makakilo city
# Processing Record 16 of Set 16 | yafran
# Processing Record 17 of Set 16 | mpika
# Processing Record 18 of Set 16 | okha
# Processing Record 19 of Set 16 | cockburn town
# Processing Record 20 of Set 16 | namuac
# Processing Record 21 of Set 16 | berberati
# Processing Record 22 of Set 16 | indiaroba
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 702

# %%
city_data_df = pd.DataFrame(city_data)
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Mount Isa      AU -20.7333  139.5000     62.37        27           0
# 1       Nikolskoye      RU  59.7035   30.7861     63.81        98          19
# 2    Srednekolymsk      RU  67.4500  153.6833     76.26        44         100
# 3            Bluff      NZ -46.6000  168.3333     44.80        92         100
# 4     Port Lincoln      AU -34.7333  135.8667     56.64        61         100
# 5  Arraial Do Cabo      BR -22.9661  -42.0278     71.46        85          52
# 6    Alice Springs      AU -23.7000  133.8833     53.15        54           0
# 7        Tuatapere      NZ -46.1333  167.6833     43.61        94         100
# 8         Ahuimanu      US  21.4447 -157.8378     85.71        75          75
# 9           Rawson      AR -43.3002  -65.1023     43.77        53          11
#
#    Wind Speed Current Description
# 0       16.11           clear sky
# 1        4.76          few clouds
# 2        8.48     overcast clouds
# 3       22.35       moderate rain
# 4        8.50     overcast clouds
# 5       20.51       broken clouds
# 6       14.97           clear sky
# 7        9.73     overcast clouds
# 8       17.27          light rain
# 9       16.17          few clouds

# %%
output_data_file = "WeatherPy_Database.csv"
city_data_df.to_csv(output_data_file)
